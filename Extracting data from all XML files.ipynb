# %%
# Dataset EPO 14.1 EP bibliographic data EBD
,
     # https://publication-bdds.apps.epo.org/raw-data/products/public/product/10
import os
import re
import pandas as pd
import xml.etree.ElementTree as ET
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

# %%
# The directory containing all XML files
directory_path = "/Users/lilitpoghosyan/Downloads/Data/Dataset EPO14.1"
files = [f for f in os.listdir(directory_path) if f.endswith(".txt")]
print(f"Total `.txt` files found: {len(files)}")
print(files[:5])
# Out:
# Total `.txt` files found: 56
# ['s362506b 2.txt', 's362436a.txt', 's362504b.txt', 's362441b.txt', 's362436b.txt']

# %%
data_list = []

# Iterating over all .txt files in the directory
for filename in os.listdir(directory_path):
    if filename.endswith(".txt"): 
        file_path = os.path.join(directory_path, filename)
        print(f"Processing file: {filename}")

        try:
            with open(file_path, "r", encoding="utf-8") as file:
                xml_content = file.read().strip()

            # Extracting individual patents from XML (each <ep-bulletin> represents a patent section)
            patent_sections = re.findall(r'(<ep-bulletin.*?</ep-bulletin>)', xml_content, re.DOTALL)

            print(f"Total Patents Found in {filename}: {len(patent_sections)}")

            # Loop through each extracted patent
            for idx, patent_xml in enumerate(patent_sections):
                try:
                    root = ET.fromstring(patent_xml)  

                    # Metadata
                    patent_id = root.attrib.get("id", "N/A")
                    doc_number = root.attrib.get("doc-number", "N/A")
                    publication_date = root.attrib.get("date-publ", "N/A")
                    country = root.attrib.get("country", "N/A")
                    kind = root.attrib.get("kind", "N/A")

                    # Application details
                    app_number = root.find(".//B210").text if root.find(".//B210") is not None else "N/A"
                    filing_date = root.find(".//B220/date").text if root.find(".//B220/date") is not None else "N/A"

                    # Priority details
                    priority_numbers = [pri.text for pri in root.findall(".//B300/B310") if pri.text]
                    priority_dates = [pri_date.text for pri_date in root.findall(".//B300/B320/date") if pri_date.text]
                    priority_numbers = ", ".join(priority_numbers) if priority_numbers else "N/A"
                    priority_dates = ", ".join(priority_dates) if priority_dates else "N/A"

                    # Title 
                    title = "N/A"
                    b540 = root.find(".//B540")
                    if b540 is not None:
                        b541_tags = b540.findall("B541")
                        b542_tags = b540.findall("B542")
                        for i in range(len(b541_tags)):
                            if b541_tags[i].text == "en":  # Check if it's English
                                if i < len(b542_tags):
                                    title = b542_tags[i].text
                                break

                    # IPC Codes
                    classifications = [elem.text for elem in root.findall(".//classification-ipcr/text") if elem.text]
                    classification_codes = ", ".join(classifications) if classifications else "N/A"

                    # Applicant details
                    applicant_name = root.find(".//B700/B710/B711/snm")
                    applicant_name = applicant_name.text if applicant_name is not None else "N/A"
                    applicant_country = root.find(".//B700/B710/B711/adr/ctry")
                    applicant_country = applicant_country.text if applicant_country is not None else "N/A"

                    # Designated countries where patent is valid
                    designated_countries = [ctry.text for ctry in root.findall(".//B800/B840/ctry")]
                    designated_countries = ", ".join(designated_countries) if designated_countries else "N/A"

                  
                    data_list.append({
                        "File": filename,
                        "Patent ID": patent_id,
                        "Document Number": doc_number,
                        "Publication Date": publication_date,
                        "Country": country,
                        "Patent Type": kind,
                        "Application Number": app_number,
                        "Filing Date": filing_date,
                        "Priority Numbers": priority_numbers,
                        "Priority Dates": priority_dates,
                        "Title": title,
                        "IPC Codes": classification_codes,
                        "Applicant Name": applicant_name,
                        "Applicant Country": applicant_country,
                        "Designated Countries": designated_countries
                    })

                except ET.ParseError as e:
                    print(f"Error parsing patent {idx + 1} in {filename}: {e}")

        except Exception as e:
            print(f"Error reading file {filename}: {e}")
# Out:
# Processing file: s362506b 2.txt
# Total Patents Found in s362506b 2.txt: 4532
# Processing file: s362436a.txt
# Total Patents Found in s362436a.txt: 22986
# Processing file: s362504b.txt
# Total Patents Found in s362504b.txt: 18606
# Processing file: s362441b.txt
# Total Patents Found in s362441b.txt: 92384
# Processing file: s362436b.txt
# Total Patents Found in s362436b.txt: 85754
# Processing file: s362504a.txt
# Total Patents Found in s362504a.txt: 27599
# Processing file: s362441a.txt
# Total Patents Found in s362441a.txt: 23866
# Processing file: s362505a.txt
# Total Patents Found in s362505a.txt: 15989
# Processing file: s362440a.txt
# Total Patents Found in s362440a.txt: 27461
# Processing file: s362437b.txt
# Total Patents Found in s362437b.txt: 26272
# Processing file: s362505b.txt
# Total Patents Found in s362505b.txt: 6431
# Processing file: s362440b.txt
# Total Patents Found in s362440b.txt: 28325
# Processing file: s362437a.txt
# Total Patents Found in s362437a.txt: 19844
# Processing file: s362447a.txt
# Total Patents Found in s362447a.txt: 24714
# Processing file: s362506a 2.txt
# Total Patents Found in s362506a 2.txt: 18201
# Processing file: s362451a.txt
# Total Patents Found in s362451a.txt: 24993
# Processing file: s362447b.txt
# Total Patents Found in s362447b.txt: 76990
# Processing file: s362451b.txt
# Total Patents Found in s362451b.txt: 119842
# Processing file: s362450b.txt
# Total Patents Found in s362450b.txt: 17156
# Processing file: s362446b.txt
# Total Patents Found in s362446b.txt: 54361
# Processing file: s362431a.txt
# Total Patents Found in s362431a.txt: 29258
# Processing file: s362450a.txt
# Total Patents Found in s362450a.txt: 26265
# Processing file: s362446a.txt
# Total Patents Found in s362446a.txt: 31641
# Processing file: s362431b.txt
# Total Patents Found in s362431b.txt: 13293
# Processing file: s362449b.txt
# Total Patents Found in s362449b.txt: 76946
# Processing file: s362445a.txt
# Total Patents Found in s362445a.txt: 25413
# Processing file: s362432b.txt
# Total Patents Found in s362432b.txt: 41581
# Processing file: s362440b 2.txt
# Total Patents Found in s362440b 2.txt: 28325
# Processing file: s362449a.txt
# Total Patents Found in s362449a.txt: 26419
# Processing file: s362445b.txt
# Total Patents Found in s362445b.txt: 16367
# Processing file: s362432a.txt
# Total Patents Found in s362432a.txt: 29528
# Processing file: s362433a.txt
# Total Patents Found in s362433a.txt: 26844
# Processing file: s362444b.txt
# Total Patents Found in s362444b.txt: 59057
# Processing file: s362501b.txt
# Total Patents Found in s362501b.txt: 8320
# Processing file: s362448a.txt
# Total Patents Found in s362448a.txt: 26703
# Processing file: s362452b.txt
# Total Patents Found in s362452b.txt: 30776
# Processing file: s362433b.txt
# Total Patents Found in s362433b.txt: 82121
# Processing file: s362444a.txt
# Total Patents Found in s362444a.txt: 29500
# Processing file: s362501a.txt
# Total Patents Found in s362501a.txt: 26085
# Processing file: s362448b.txt
# Total Patents Found in s362448b.txt: 71386
# Processing file: s362452a.txt
# Total Patents Found in s362452a.txt: 27854
# Processing file: s362443b.txt
# Total Patents Found in s362443b.txt: 11528
# Processing file: s362506b.txt
# Total Patents Found in s362506b.txt: 4532
# Processing file: s362434a.txt
# Total Patents Found in s362434a.txt: 22952
# Processing file: s362438b.txt
# Total Patents Found in s362438b.txt: 7056
# Processing file: s362443a.txt
# Total Patents Found in s362443a.txt: 27416
# Processing file: s362506a.txt
# Total Patents Found in s362506a.txt: 18201
# Processing file: s362440a 2.txt
# Total Patents Found in s362440a 2.txt: 27461
# Processing file: s362434b.txt
# Total Patents Found in s362434b.txt: 68867
# Processing file: s362438a.txt
# Total Patents Found in s362438a.txt: 21286
# Processing file: s362439a.txt
# Total Patents Found in s362439a.txt: 23682
# Processing file: s362435b.txt
# Total Patents Found in s362435b.txt: 58075
# Processing file: s362442a.txt
# Total Patents Found in s362442a.txt: 26568
# Processing file: s362439b.txt
# Total Patents Found in s362439b.txt: 6850
# Processing file: s362435a.txt
# Total Patents Found in s362435a.txt: 28929
# Processing file: s362442b.txt
# Total Patents Found in s362442b.txt: 93381

# %%
df = pd.DataFrame(data_list)
df.head()
# Save structured data to CSV
#output_file = "all_parsed_patent_data.csv"
#df.to_csv(output_file, index=False)
#print(f"Extracted structured data from all files and saved to {output_file}")
# Out:
#              File     Patent ID Document Number Publication Date Country  \
# 0  s362506b 2.txt  EP05027585B1         1733882         20250205      EP
# 1  s362506b 2.txt  EP07118196B1         1911589         20250205      EP
# 2  s362506b 2.txt  EP07819107B1         2091700         20250205      EP
# 3  s362506b 2.txt  EP08864353B1         2231029         20250205      EP
# 4  s362506b 2.txt  EP09003618B1         2101353         20250205      EP
#
#   Patent Type Application Number Filing Date Priority Numbers Priority Dates  \
# 0          B1         05027585.8    20051216       2005176463       20050616
# 1          B1         07118196.0    20071010       2006277950       20061011
# 2          B1         07819107.9    20071018     102006049956       20061019
# 3          B1         08864353.1    20081219          16221 P       20071221
# 4          B1         09003618.7    20090312       2008063006       20080312
#
#                                                Title  \
# 0                        Ink jet head driving method
# 1   Driving method and driving device of inkjet head
# 2  SYSTEM AND METHOD FOR AUTOMATED GRINDING AND/O...
# 3  DEVICES FOR ENDOSCOPICALLY CREATING AN ANASTOM...
# 4                               Semiconductor device
#
#                                            IPC Codes Applicant Name  \
# 0  B41J   2/045       20060101AFI20060928BHEP    ...            N/A
# 1  B41J   2/045       20060101AFI20080129BHEP    ...            N/A
# 2  B25J   9/16        20060101AFI20080509BHEP    ...            N/A
# 3  A61B  17/11        20060101AFI20230307BHEP    ...            N/A
# 4  H01L  21/8234      20060101AFI20230907BHEP    ...            N/A
#
#   Applicant Country                               Designated Countries
# 0               N/A                                         DE, FR, GB
# 1               N/A                                             DE, GB
# 2               N/A  AT, BE, BG, CH, CY, CZ, DE, DK, EE, ES, FI, FR...
# 3               N/A  AT, BE, BG, CH, CY, CZ, DE, DK, EE, ES, FI, FR...
# 4               N/A                                                 DE

# %%
pd.set_option("display.max_colwidth",None)  
pd.set_option("display.max_rows", 40)  
pd.set_option("display.max_columns", None)

# %%
display(df.head(5))
# Out:
#              File     Patent ID Document Number Publication Date Country  \
# 0  s362506b 2.txt  EP05027585B1         1733882         20250205      EP
# 1  s362506b 2.txt  EP07118196B1         1911589         20250205      EP
# 2  s362506b 2.txt  EP07819107B1         2091700         20250205      EP
# 3  s362506b 2.txt  EP08864353B1         2231029         20250205      EP
# 4  s362506b 2.txt  EP09003618B1         2101353         20250205      EP
#
#   Patent Type Application Number Filing Date Priority Numbers Priority Dates  \
# 0          B1         05027585.8    20051216       2005176463       20050616
# 1          B1         07118196.0    20071010       2006277950       20061011
# 2          B1         07819107.9    20071018     102006049956       20061019
# 3          B1         08864353.1    20081219          16221 P       20071221
# 4          B1         09003618.7    20090312       2008063006       20080312
#
#                                                                      Title  \
# 0                                              Ink jet head driving method
# 1                         Driving method and driving device of inkjet head
# 2  SYSTEM AND METHOD FOR AUTOMATED GRINDING AND/OR POLISHING OF WORKPIECES
# 3                       DEVICES FOR ENDOSCOPICALLY CREATING AN ANASTOMOSIS
# 4                                                     Semiconductor device
#
#                                                                                                                                                                                                                                                                                                                                                                     IPC Codes  \
# 0                                                                                                                                                                                                                                                                                                                          B41J   2/045       20060101AFI20060928BHEP
# 1                                                                                                                                                                                                                                                                                                                          B41J   2/045       20060101AFI20080129BHEP
# 2                                                                                                                                                                                                                                                                                                                          B25J   9/16        20060101AFI20080509BHEP
# 3                                                                                                                                                                                                                  A61B  17/11        20060101AFI20230307BHEP        , A61B  17/3205      20060101ALN20230307BHEP        , A61B  17/00        20060101ALN20230307BHEP
# 4  H01L  21/8234      20060101AFI20230907BHEP        , H01L  27/088       20060101ALI20230907BHEP        , H01L  27/02        20060101ALI20230907BHEP        , H01L  27/12        20060101ALN20230907BHEP        , H01L  21/84        20060101ALN20230907BHEP        , H01L  29/66        20060101ALN20230907BHEP        , H01L  29/78        20060101ALN20230907BHEP
#
#   Applicant Name Applicant Country  \
# 0            N/A               N/A
# 1            N/A               N/A
# 2            N/A               N/A
# 3            N/A               N/A
# 4            N/A               N/A
#
#                                                                                                                      Designated Countries
# 0                                                                                                                              DE, FR, GB
# 1                                                                                                                                  DE, GB
# 2          AT, BE, BG, CH, CY, CZ, DE, DK, EE, ES, FI, FR, GB, GR, HU, IE, IS, IT, LI, LT, LU, LV, MC, MT, NL, PL, PT, RO, SE, SI, SK, TR
# 3  AT, BE, BG, CH, CY, CZ, DE, DK, EE, ES, FI, FR, GB, GR, HR, HU, IE, IS, IT, LI, LT, LU, LV, MC, MT, NL, NO, PL, PT, RO, SE, SI, SK, TR
# 4                                                                                                                                      DE

# %%
# Converting filing date format
df["Filing Date"] = pd.to_datetime(df["Filing Date"], format="%Y%m%d", errors="coerce")
print(df[["Filing Date"]].head())
# Out:
#   Filing Date
# 0  2005-12-16
# 1  2007-10-10
# 2  2007-10-18
# 3  2008-12-19
# 4  2009-03-12

# %%
# Extracting the year from the Filing Date column
df["Filing Year"] = df["Filing Date"].dt.year
print(df[["Filing Date", "Filing Year"]].head())
# Out:
#   Filing Date  Filing Year
# 0  2005-12-16         2005
# 1  2007-10-10         2007
# 2  2007-10-18         2007
# 3  2008-12-19         2008
# 4  2009-03-12         2009

# %%
missing_dates = df["Filing Date"].isnull().sum()

# %%
filing_trends = df["Filing Year"].value_counts().sort_index()
plt.figure(figsize=(12, 6))
plt.plot(filing_trends.index, filing_trends.values, marker="o", linestyle="-", color="skyblue")
plt.xlabel("Year")
plt.ylabel("Number of Patents Filed")
plt.title("Patent Filing Trends Over Time")
plt.grid(True)
min_year = filing_trends.index.min()
max_year = filing_trends.index.max()
all_years = np.arange(min_year, max_year + 1, 1) 
plt.xticks(all_years, rotation=45)  
plt.tight_layout()
plt.show()

# %%
# IPC Codes N/A = "The designation of the inventor has not yet been filed"
pattern = r'\b[A-Z]\d{2}[A-Z]?\s+\d{1,3}/\d{2}\b'
df['Extracted IPC Codes'] = df['IPC Codes'].apply(lambda x: ', '.join(re.findall(pattern, str(x))) if pd.notna(x) else 'N/A')
df['Extracted IPC Codes'] = df['Extracted IPC Codes'].replace('', 'N/A')
cleaned_na_count = (df['Extracted IPC Codes'] == 'N/A').sum()
print(f"Cleaned 'N/A' count in 'Extracted IPC Codes': {cleaned_na_count}")
# Out:
# Cleaned 'N/A' count in 'Extracted IPC Codes': 100230

# %%
all_extracted_codes = [code.strip() for row in df['Extracted IPC Codes'].str.split(', ').dropna() for code in row]
code_counts = Counter(all_extracted_codes)
code_df = pd.DataFrame(code_counts.most_common(), columns=['IPC Code', 'Frequency'])
print(code_df)
# Out:
#           IPC Code  Frequency
# 0              N/A     100230
# 1      H04L   5/00      30739
# 2      A61P  35/00      25957
# 3      A61B   5/00      24378
# 4      H04L   9/40      16846
# ...            ...        ...
# 55439  A45D  20/38          1
# 55440  C07D 307/71          1
# 55441  B27F   7/34          1
# 55442  G04B   5/12          1
# 55443  F41A   9/57          1
#
# [55444 rows x 2 columns]

# %%
# Exclude 'N/A' values from the extracted IPC codes
valid_ipc_codes = df[df['Extracted IPC Codes'] != 'N/A']
all_extracted_codes = [code.strip() for row in valid_ipc_codes['Extracted IPC Codes'].str.split(', ').dropna() for code in row]
code_counts = Counter(all_extracted_codes)
code_df = pd.DataFrame(code_counts.most_common(), columns=['IPC Code', 'Frequency'])
#'Top 10 Most Frequent IPC Codes (Single file)
plt.figure(figsize=(10, 6))
plt.barh(code_df['IPC Code'][:10], code_df['Frequency'][:10], color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('IPC Code')
plt.title('Top 10 Most Frequent IPC Codes')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
